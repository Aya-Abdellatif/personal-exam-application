# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
dataset = pd.read_csv("all_data.csv")

# %%
dataset.head()
# Out:
#                topic subTopic  \
# 0  Basic Peripherals      I2C
# 1  Basic Peripherals      I2C
# 2  Basic Peripherals      I2C
# 3  Basic Peripherals      I2C
# 4  Basic Peripherals      I2C
#
#                                         questionText       choiceA  \
# 0                           What does I2C stand for?      inter-IC
# 1                       Which company developed I2C?         Intel
# 2  Which of the following is the most known simpl...           I2C
# 3           Which are the two lines used in the I2C?  SDA and SPDR
# 4          Which of the following developed P82B715?       Philips
#
#         choiceB                     choiceC              choiceD answer
# 0      intra-IC  individual integrated chip             intel IC      a
# 1      Motorola                    Phillips                  IBM      c
# 2   Serial port               Parallel port                  SPI      a
# 3  SPDR and SCL                 SDA and SCL  SCL and status line      c
# ...

# %%
dataset.describe()
# Out:
#                   topic subTopic              questionText choiceA choiceB  \
# count               387      387                       387     387     387
# unique                4       29                       387     296     306
# top     Embedded system      I2C  What does I2C stand for?    8086    DRAM
# freq                176       21                         1      10       7
#
#        choiceC                choiceD answer
# count      387                    387    387
# unique     313                    306      4
# top      EPROM  None of the mentioned      a
# freq         7                     14    144

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   topic         387 non-null    object
#  1   subTopic      387 non-null    object
#  2   questionText  387 non-null    object
#  3   choiceA       387 non-null    object
#  4   choiceB       387 non-null    object
#  5   choiceC       387 non-null    object
#  6   choiceD       387 non-null    object
#  7   answer        387 non-null    object
# dtypes: object(8)
# memory usage: 24.3+ KB

# %%
dataset.shape
# Out:
# (413, 8)

# %% [markdown]
# Visualizations

# %%
topic_counts = dataset["topic"].value_counts()
plt.figure(figsize=(12, 8))
plt.bar(x = topic_counts.index, height = topic_counts, color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Question Distribution by Topic", fontsize = 16, fontweight = "bold")
plt.ylabel("Number of Questions", fontsize = 13)
plt.show()

# %%
# Count the number of unique subtopics for each topic
subTopic_counts_per_topic = dataset.groupby('topic')['subTopic'].nunique()
plt.figure(figsize=(12, 8))
plt.bar(x = subTopic_counts_per_topic.index, height = subtopic_counts_per_topic, color = "midnightblue")
plt.title("Number of SubTopics per Topic", fontsize=16, fontweight="bold")
plt.xlabel("Topic", fontsize=13)
plt.ylabel("Number of SubTopics", fontsize=13)
plt.xticks(rotation=45, fontsize=13)
plt.yticks(fontsize=13)
plt.show()
